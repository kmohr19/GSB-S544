# %% [markdown]
# 0. Load the `penguins` dataset from the `palmerpenguins` library, as well as any other libraries you need.

# %%
# %pip install palmerpenguins
# Out:
# Collecting palmerpenguins
#   Downloading palmerpenguins-0.1.4-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from palmerpenguins) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from palmerpenguins) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->palmerpenguins) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->palmerpenguins) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->palmerpenguins) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->palmerpenguins) (1.17.0)
# Downloading palmerpenguins-0.1.4-py3-none-any.whl (17 kB)
# Installing collected packages: palmerpenguins
# Successfully installed palmerpenguins-0.1.4

# %%
from palmerpenguins import load_penguins
import pandas as pd

penguins = load_penguins()
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %% [markdown]
# 1. Write a function that takes in information about a penguin, and returns one of the following definitions:
#
# *   "Big Mouth Billy": Male penguins with bill length times bill depth greater than 800.
# *   "Dainty Daisy": Female penguins with flipper length less than 5% of body mass.
# *   "Average Adelie:" Any Adelie penguins that do not fall into either category.
# *   "Other": Any penguins that do not fall into any of the categories.

# %%
def penguins_classification(row):

    # Big Mouth Billy: male, bill_length * bill_depth > 800
    if (row["sex"] == "male") and (row["bill_length_mm"] * row["bill_depth_mm"] > 800):
        return "Big Mouth Billy"

    # Dainty Daisy: female, flipper_length < 5% of body_mass
    elif (row["sex"] == "female") and (row["flipper_length_mm"] < 0.05 * row["body_mass_g"]):
        return "Dainty Daisy"

    # Average Adelie: Adelie penguins not in either category
    elif (row["species"] == "Adelie"):
        return "Average Adelie"

    # Other
    else:
        return "Other"

# %% [markdown]
# :2. Use an iterable function to create a new variable called `category_name` that adds these labels.

# %%
penguins["category_name"] = penguins.apply(penguins_classification, axis=1)

penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year    category_name
# 0         3750.0    male  2007   Average Adelie
# 1         3800.0  female  2007     Dainty Daisy
# 2         3250.0  female  2007   Average Adelie
# 3            NaN     NaN  2007   Average Adelie
# 4         3450.0  female  2007   Average Adelie
# ..           ...     ...   ...              ...
# 339       4000.0    male  2009  Big Mouth Billy
# 340       3400.0  female  2009            Other
# 341       3775.0    male  2009  Big Mouth Billy
# 342       4100.0    male  2009  Big Mouth Billy
# 343       3775.0  female  2009            Other
#
# [344 rows x 9 columns]

# %% [markdown]
# 3. Run the following code to find the counts for each type.
#
# ---

# %%
penguins.value_counts("category_name")
# Out:
# category_name
# Average Adelie     127
# Other               84
# Big Mouth Billy     71
# Dainty Daisy        62
# Name: count, dtype: int64
